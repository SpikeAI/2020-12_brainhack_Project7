# %% [markdown]
# ## dot stimulus
#
# see https://github.com/laurentperrinet/Khoei_2017_PLoSCB/blob/master/scripts/MotionParticlesFLE.py#L1946

# %%
# %run boilerplate.ipynb
# Out:
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 7.18.1
#
# numpy     : 1.19.2
# matplotlib: 3.3.2
# pyNN      : 0.9.5
# neo       : 0.8.0
# moviepy   : 1.0.3
# imageio   : 2.9.0
#
# Compiler    : GCC 9.3.0
# OS          : Linux
# Release     : 5.4.0-53-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# Hostname: inv-ope-de06
#
# Git hash: 28f42d2c04bd90abeefe828e99dc35fc996a55fa
#
# Git repo: https://github.com/SpikeAI/2020-11_brainhack_Project7
#
# Git branch: main

# %%
time_bins = 100
N_pop = 128**2
width = int(np.sqrt(N_pop))

input_movie = generate_dot(width, width,
                        time_bins,
                        dot_size = 0.1,
                        im_noise = .3,
                        im_contrast = .9)
minmax(input_movie)

input_movie = rectify(input_movie)

minmax(input_movie)
# Out:
# movie.min()=-1.0 - movie.max()=1.0
# movie.min()=0.0 - movie.max()=1.0

# %% [markdown]
# ## testing

# %%
fnames = generate_images(input_movie, label='image', output_dir=output_dir, verbose=False)
print(f'{fnames[:10]=}')
# Out:
# fnames[:10]=['output/image_000.png', 'output/image_001.png', 'output/image_002.png', 'output/image_003.png', 'output/image_004.png', 'output/image_005.png', 'output/image_006.png', 'output/image_007.png', 'output/image_008.png', 'output/image_009.png']

# %%
moviename = 'test.mp4'
moviename = make_mp4(moviename, fnames, fps)
print(f'{moviename=}')
# Out:
# t:  46%|████▌     | 46/100 [00:00<00:00, 459.77it/s, now=None]
# Moviepy - Building video test.mp4.
# Moviepy - Writing video test.mp4
# Moviepy - Done !
# Moviepy - video ready test.mp4
# moviename='test.mp4'

# %%
show(moviename, width=width)
# Out:
# <div align=middle><video width='128' autoplay='True' loop='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# In one line:

# %%
show(make_mp4(f'{output_dir}/test.mp4', generate_images(input_movie, label='image', output_dir=output_dir, verbose=False), fps), width=width)
# Out:
# t:  46%|████▌     | 46/100 [00:00<00:00, 455.10it/s, now=None]
# Moviepy - Building video output/test.mp4.
# Moviepy - Writing video output/test.mp4
# Moviepy - Done !
# Moviepy - video ready output/test.mp4
# <div align=middle><video width='128' autoplay='True' loop='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# # more examples

# %%
generate_dot?
# Out:
# Signature:
# generate_dot(
#     N_X,
#     N_Y,
#     N_frame,
#     X_0=-1.0,
#     Y_0=0.0,
#     V_X=1.0,
#     V_Y=0.0,
#     dot_size=0.05,
#     blank_duration=0.0,
#     blank_start=0.0,
#     flash_duration=0.0,
#     flash_start=0.0,
#     width=2.0,
#     im_noise=0.05,
#     im_contrast=1.0,
#     NoisyTrajectory=False,
#     traj_Xnoise=0,
#     traj_Vnoise=0,
#     reversal=False,
#     hard=False,
#     second_order=False,
#     f=8,
#     texture=False,
#     sf_0=0.15,
#     pink_noise=False,
#     do_clip=True,
#     **kwargs,
# )
# Docstring: >> pylab.imshow(concatenate((image[16,:,:],image[16,:,:]), axis=-1))
# File:      ~/quantic/science/WaveAlberto/2020-12_brainhack_Project7/input/<ipython-input-1-0d6f140c45f6>
# Type:      function

# %%
input_movie = rectify(generate_dot(width, width,
                        time_bins,
                        X_0=0., Y_0=-1.0, #initial position
                        V_Y=1.0,
                        V_X=0.0,
                        dot_size = 0.1,
                        im_noise = .3,
                        im_contrast = .9))

# %%
show(make_mp4(f'{output_dir}/test_vert.mp4', generate_images(input_movie, label='image', output_dir=output_dir, verbose=False), fps), width=width)
# Out:
# t:  43%|████▎     | 43/100 [00:00<00:00, 421.31it/s, now=None]
# Moviepy - Building video output/test_vert.mp4.
# Moviepy - Writing video output/test_vert.mp4
# Moviepy - Done !
# Moviepy - video ready output/test_vert.mp4
# <div align=middle><video width='128' autoplay='True' loop='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
input_movie = rectify(generate_dot( width, width,
                                    time_bins,
                                    flash_start=0.2,
                                    flash_duration=0.6,
                                    dot_size = 0.1,
                                    im_noise = .3,
                                    im_contrast = .9))

# %%
show(make_mp4(f'{output_dir}/test_stop.mp4', generate_images(input_movie, label='image', output_dir=output_dir, verbose=False), fps), width=width)
# Out:
# t:  49%|████▉     | 49/100 [00:00<00:00, 485.30it/s, now=None]
# Moviepy - Building video output/test_stop.mp4.
# Moviepy - Writing video output/test_stop.mp4
# Moviepy - Done !
# Moviepy - video ready output/test_stop.mp4
# <div align=middle><video width='128' autoplay='True' loop='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
