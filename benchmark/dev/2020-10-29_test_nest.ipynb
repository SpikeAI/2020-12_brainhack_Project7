# %%
import numpy as np
import VisionSNN
#import pyNN.spiNNaker as sim

# loading args
args = VisionSNN.init()
args.N_pop = 900
args.dt = 1 # ms
args.min_delay = 1 # ms
args.max_delay = 100 # ms
args.simtime = 1000 # ms # timebin = simtime / dt
args.waveVelocity = 0.1 # [mm/ms] in Muller 2014 is 0.35 m/s http://www.int.univ-amu.fr/IMG/pdf/Muller_Nature_Communications2014.pdf
args.scalePar = 0.001 # distance scale par to have millimiters instead of microns
args.E_expPar = 3.0
args.I_expPar = 3.0
args.tag = '2020-12-03' + '_N_pop=' + str(args.N_pop) + "_E_expPar=" + str(args.E_expPar) + "_I_expPar=" + str(args.I_expPar) + "_sim=" + str(args.simulator)
b = VisionSNN.Bump2D(args)
args
# Out:
# Namespace(E_expPar=3.0, E_v_tresh=-50, E_weight=0.08, Eone_weight=0.08, I_expPar=3.0, I_v_tresh=-50, I_weight=0.08, Ione_weight=0.08, N_pop=900, N_tau=30.0, do_save=True, dt=1, figpath='figures', im_contrast=0.1, im_noise=0.0, max_delay=100, min_delay=1, outpath='outputs', scalePar=0.001, simtime=1000, simulator='default', tag='2020-12-032_N_pop=900_E_expPar=3.0_I_expPar=3.0_sim=default', verbose=True, waveVelocity=0.1)

# %%
# runs simulations
c = b.run()
# Out:
# /home/laurent/.local/lib/python3.8/site-packages/pyNN/nest/__init__.py:53: UserWarning:Unable to install NEST extensions. Certain models may not be available.
# /usr/lib/python3.8/dist-packages/nest/lib/hl_api_helper.py:127: UserWarning:
# ResetNetwork is deprecated and will be removed in NEST 3.0.
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# CSAConnector: libneurosim support not available in NEST.
# Falling back on PyNN's default CSAConnector.
# Please re-compile NEST using --with-libneurosim=PATH
# pop Population(900, IF_cond_exp(<parameters>), structure=Grid2D(aspect_ratio=1, dx=1.0, dy=1.0, x0=0.0, y0=0.0, z=0, fill_order='sequential'), label='2D-bumpNN')
# pop Population(900, IF_cond_exp(<parameters>), structure=Grid2D(aspect_ratio=1, dx=1.0, dy=1.0, x0=0.0, y0=0.0, z=0, fill_order='sequential'), label='2D-bumpNN')
# connType is float
# connType is string
# connType is string
# connType is float
# connType is string
# connType is string
# connType is string
# connType is string
# gsyn_inh
# gsyn_inh
# v
# v
# gsyn_exc
# gsyn_exc
# v
# gsyn_exc
# gsyn_inh
# v
# gsyn_exc
# gsyn_inh

# %%
# load results
c = b.run() #to load the results
# Out:
# Loaded data
# v
# gsyn_exc
# gsyn_inh
# v
# gsyn_exc
# gsyn_inh

# %%
# TO-DO
# insert network structure from past notebook with benvenuti's phenomenological model
# b.plot_network('True')

# %%
b.plot_projections('True')
# Out:
# /home/laurent/quantic/science/WaveAlberto/2020-12_brainhack_Project7/benchmark/VisionSNN/probabilistic_2D_bump_attractor.py:1628: UserWarning:This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
# /home/laurent/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning:`distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
b.plot_overview('true')

# %%
b.plot_spikes('True')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cc15c0131f8d> in <module>
# ----> 1 b.plot_spikes('True')
#
# ~/quantic/science/WaveAlberto/2020-12_brainhack_Project7/benchmark/VisionSNN/probabilistic_2D_bump_attractor.py in plot_spikes(self, showArg)
#     402
#     403         ax2 = fig.add_subplot(3,1,1)
# --> 404         im2 = plt.eventplot(self.spikeSources.segments[0].spiketrains, colors='black')
#     405         ax2.set_title("Spikes in Sources Layer ", y=1.10, fontsize=16)
#     406         ax2.set_xlabel("[ms]", fontsize=14);
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in eventplot(positions, orientation, lineoffsets, linelengths, linewidths, colors, linestyles, data, **kwargs)
#    2616         linelengths=1, linewidths=None, colors=None,
#    2617         linestyles='solid', *, data=None, **kwargs):
# -> 2618     return gca().eventplot(
#    2619         positions, orientation=orientation, lineoffsets=lineoffsets,
#    2620         linelengths=linelengths, linewidths=linewidths, colors=colors,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in eventplot(self, positions, orientation, lineoffsets, linelengths, linewidths, colors, linestyles, **kwargs)
#    1470                 zip(positions, lineoffsets, linelengths, linewidths,
#    1471                     colors, linestyles):
# -> 1472             coll = mcoll.EventCollection(position,
#    1473                                          orientation=orientation,
#    1474                                          lineoffset=lineoffset,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, positions, orientation, lineoffset, linelength, linewidth, color, linestyle, antialiased, **kwargs)
#    1530         self._lineoffset = lineoffset
#    1531         self.set_orientation(orientation)
# -> 1532         self.set_positions(positions)
#    1533
#    1534     def get_positions(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/collections.py in set_positions(self, positions)
#    1549         pos_idx = 0 if self.is_horizontal() else 1
#    1550         segments = np.empty((len(positions), 2, 2))
# -> 1551         segments[:, :, pos_idx] = np.sort(positions)[:, None]
#    1552         segments[:, 0, 1 - pos_idx] = lineoffset + linelength / 2
#    1553         segments[:, 1, 1 - pos_idx] = lineoffset - linelength / 2
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     989     else:
#     990         a = asanyarray(a).copy(order="K")
# --> 991     a.sort(axis=axis, kind=kind, order=order)
#     992     return a
#     993
#
# TypeError: sort() got an unexpected keyword argument 'axis'

# %%
fr = b.plot_firingrates('True')

# %%
b.plot_abstract(fr[1], fr[2], 'True')

# %%
b.plot_signalprocessing('True')

# %%
b.plot_voltage('True')

# %%
b.plot_conductances('True')

# %%
b.plot_movingbumps() #check also output/figures/moving_bump folder

# %%
#out = b.plot_movingWaves()
