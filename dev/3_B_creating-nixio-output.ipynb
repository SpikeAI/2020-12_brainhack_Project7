# %% [markdown]
# # balanced network
#
# Let's start with a rather complete example modified from
#
# http://neuralensemble.org/docs/PyNN/examples/VAbenchmarks.html

# %%
# %run 3_boilerplate.ipynb
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1
# 2020-12-03T14:48:36+00:00
#
# CPython 3.6.9
# IPython 7.15.0
#
# numpy 1.19.0
# matplotlib 3.2.2
# pyNN 0.9.4
# neo 0.6.1
# nixio 1.4.9
#
# compiler   : GCC 8.4.0
# system     : Linux
# release    : 4.4.0-87-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 32
# interpreter: 64bit
# host name  : 134ac8ebb3bc
# Git hash   : cf8ba08551712115eb122f4233f89394190dcd99
# Git repo   : https://github.com/SpikeAI/2020-11_brainhack_Project7
# Git branch : main

# %% [markdown]
# ## running it...

# %%
run(do_nixio=True)
# Out:
# 2020-12-03 14:48:36 INFO: Read cfg files: /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/spinnaker/.spynnaker.cfg
# 2020-12-03 14:48:36 INFO: Will search these locations for binaries: /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2020-12-03 14:48:36 WARNING: A timestep was entered that has forced sPyNNaker to automatically slow the simulation down from real time by a factor of 10. To remove this automatic behaviour, please enter a timescaleFactor value in your .spynnaker.cfg
# 2020-12-03 14:48:36 INFO: Setting time scale factor to 10.
# 2020-12-03 14:48:36 INFO: Setting machine time step to 100 micro-seconds.
# 2020-12-03 14:48:36 WARNING: Extra params {'threads': 1, 'filename': 'va.xml', 'label': 'VA'} have been applied to the setup command which we do not consider
# 2020-12-03 14:48:36 INFO: Simulating for 10000 0.1ms timesteps using a hardware timestep of 10us
# 2020-12-03 14:48:36 INFO: Starting execution process
# ['/home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/spinnaker/.spynnaker.cfg']
# 0 Creating cell populations...
# 0 Initialising membrane potential to random values...
# 0 Connecting populations...
# 0 Setting up recording...
# 0 Running simulation...
# 2020-12-03 14:48:40 INFO: Time 0:00:03.330072 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:48:49 INFO: Time 0:00:09.146307 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:48:54 INFO: Time 0:00:05.238058 taken by PartitionAndPlacePartitioner
# Created spalloc job 5540002
# 2020-12-03 14:48:54 INFO: Created spalloc job 5540002
# Waiting for board power commands to complete.
# 2020-12-03 14:48:54 INFO: Waiting for board power commands to complete.
# 2020-12-03 14:48:59 INFO: Time 0:00:05.051411 taken by SpallocAllocator
# 2020-12-03 14:48:59 INFO: Creating transceiver for 10.11.193.65
# 2020-12-03 14:48:59 INFO: Working out if machine is booted
# 2020-12-03 14:49:03 INFO: Attempting to boot machine
# 2020-12-03 14:49:09 INFO: Found board with version [Version: SC&MP 3.2.5 at SpiNNaker:0:0:0 (built Thu Aug  1 08:15:06 2019)]
# 2020-12-03 14:49:09 INFO: Machine communication successful
# 2020-12-03 14:49:09 INFO: Detected a machine on IP address 10.11.193.65 which has 854 cores and 120.0 links
# 2020-12-03 14:49:09 INFO: Time 0:00:09.633784 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.005716 taken by PartitionerReport
# 2020-12-03 14:49:09 INFO: Time 0:00:00.001222 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.070801 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.027316 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.007639 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.044445 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.039671 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.052290 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.006751 taken by DataInMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.006741 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.068249 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2020-12-03 14:49:09 INFO: Time 0:00:00.051229 taken by NerRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.042534 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.011562 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.032406 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.032108 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.013915 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.043254 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.029295 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.035588 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:09 INFO: Time 0:00:00.034213 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:11 INFO: Time 0:00:02.199886 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:12 INFO: Time 0:00:00.016936 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:12 INFO: Time 0:00:00.035308 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:16 INFO: Time 0:00:04.542344 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:16 INFO: Time 0:00:00.009489 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:16 INFO: Time 0:00:00.040600 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:16 INFO: Time 0:00:00.136584 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:23 INFO: Time 0:00:06.737468 taken by LoadSystemExecutableImages
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:23 INFO: Time 0:00:00.020470 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:23 INFO: Time 0:00:00.035882 taken by WriteMemoryIOData
# Executing data specifications and loading data for application vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:26 INFO: Time 0:00:02.475118 taken by HostExecuteApplicationDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:30 INFO: Time 0:00:04.297377 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:30 INFO: Time 0:00:00.047626 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:06.885972 taken by LoadApplicationExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:00.028717 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:00.011356 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:00.012187 taken by comparisonOfRoutingTablesReport
# 2020-12-03 14:49:37 INFO: Running for 1 steps for a total of 1000.0ms
# 2020-12-03 14:49:37 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:00.092578 taken by SdramUsageReportPerChip
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:00.034274 taken by ChipRuntimeUpdater
# 2020-12-03 14:49:37 INFO: creating live event connection database in /home/spinnaker/2020-11_brainhack_Project7/dev/application_generated_data_files/2020-12-03-14-48-36-631861/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: Time 0:00:00.113034 taken by DatabaseInterface
# 2020-12-03 14:49:37 INFO: ** Notifying external sources that the database is ready for reading **
# 2020-12-03 14:49:37 INFO: Time 0:00:00.001219 taken by NotificationProtocol
# 2020-12-03 14:49:37 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:37 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2020-12-03 14:49:37 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2020-12-03 14:49:37 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2020-12-03 14:49:37 INFO: Application started; waiting 10.1s for it to stop
# 2020-12-03 14:49:47 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2020-12-03 14:49:47 INFO: Time 0:00:10.194779 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:48 INFO: Time 0:00:00.614080 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:48 INFO: Time 0:00:00.100723 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:48 INFO: Time 0:00:00.053096 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:48 INFO: Time 0:00:00.052127 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:48 INFO: Time 0:00:00.051935 taken by ProfileDataGatherer
# 2020-12-03 14:49:48 INFO: get_spike_counts is inefficient as it just counts the results of get_datas('spikes')
# Getting spikes for All Cells
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-03 14:49:50 INFO: get_spike_counts is inefficient as it just counts the results of get_datas('spikes')
# Getting spikes for All Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for All Cells
# |0%                          50%                         100%|
#  ============================================================
# 0 Writing data to file...
# Getting v for All Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for All Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for All Cells
# |0%                          50%                         100%|
#  ============================================================
# --- Vogels-Abbott Network Simulation ---
# Nodes                  : 1
# Number of Neurons      : 4000
# Excitatory conductance : 4 nS
# Inhibitory conductance : 51 nS
# Excitatory rate        : 19.0806 Hz
# Inhibitory rate        : 19.8938 Hz
# Build time             : 0.00595832 s
# Simulation time        : 74.1005 s
# Writing time           : 3074.86 s
